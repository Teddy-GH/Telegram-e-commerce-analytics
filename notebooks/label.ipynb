# %%
# import necessarry libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Add the parent directory to the system path
import os 
import sys 
sys.path.append(os.path.abspath(os.path.join('..')))
# importing modules from scripts
import scripts.labeling as l
df = pd.read_csv('../data/cleaned_data.csv')
df
# Out:
#        Unnamed: 0        Channel Title    Channel Username    ID  \
# 0               0  Sheger online-store  @Shageronlinestore  7383
# 1               1  Sheger online-store  @Shageronlinestore  7382
# 2               6  Sheger online-store  @Shageronlinestore  7377
# 3               7  Sheger online-store  @Shageronlinestore  7376
# 4               8  Sheger online-store  @Shageronlinestore  7375
# ...           ...                  ...                 ...   ...
# 20763       35144               ምርጥ ዕቃ           @MerttEka    44
# 20764       35145               ምርጥ ዕቃ           @MerttEka    43
# 20765       35149               ምርጥ ዕቃ           @MerttEka    32
# 20766       35151               ምርጥ ዕቃ           @MerttEka    30
# 20767       35154               ምርጥ ዕቃ           @MerttEka    23
#
#                                                  Message  \
# 0        \n ባለሁለት ምድጃ ስቶቭ\n\n      \n\n 2000 ዋት\n ፊውዝ...
# 1      7pcs   \n\n አንድ ማራኪ ጆግና 6 መጠጫ ብርጭቆዎች\n የፈሳሽ መጠ...
# 2        -  \n\n      .\n360 °  \n100%  !!\n\nዋጋ፦    ...
# 3             \n\n          -    \nከ45cm እስከ 70cm መለጠ...
# 4             \n\n          -    \n\nዋጋ፦    2000 ብር\n...
# ...                                                  ...
# 20763                                               2500
# 20764                                ዋጋ 2500\n0983063957
# 20765  የሙያ ባለቤት መሆን መሠልጠን ነው።\nቀለም ቀቢ ሳያስፈልግዎ ቤትዎን ወይ...
# 20766  ቤትና ግቢዎን እንዲሁም የብረት እና የእንጨት ቁሳቁስዎን ቀለም ቀቢ ሳያስ...
# 20767                                        ለማዘዝ\n ://.
#
#                             Date                               Media Path
# 0      2025-06-19 06:31:31+00:00  data/photos/@Shageronlinestore_7383.jpg
# 1      2025-06-18 11:19:11+00:00  data/photos/@Shageronlinestore_7382.jpg
# 2      2025-06-18 07:12:03+00:00                                      NaN
# 3      2025-06-17 18:32:21+00:00                                      NaN
# 4      2025-06-17 18:32:20+00:00  data/photos/@Shageronlinestore_7375.jpg
# ...                          ...                                      ...
# 20763  2019-11-13 10:01:12+00:00                                      NaN
# 20764  2019-11-13 10:00:40+00:00                                      NaN
# 20765  2019-11-09 04:44:54+00:00                                      NaN
# 20766  2019-10-31 07:06:25+00:00                                      NaN
# 20767  2019-10-27 13:38:49+00:00                                      NaN
#
# [20768 rows x 7 columns]

# %%
df.drop(columns='Unnamed: 0')
# Out:
#              Channel Title    Channel Username    ID  \
# 0      Sheger online-store  @Shageronlinestore  7383
# 1      Sheger online-store  @Shageronlinestore  7382
# 2      Sheger online-store  @Shageronlinestore  7377
# 3      Sheger online-store  @Shageronlinestore  7376
# 4      Sheger online-store  @Shageronlinestore  7375
# ...                    ...                 ...   ...
# 20763               ምርጥ ዕቃ           @MerttEka    44
# 20764               ምርጥ ዕቃ           @MerttEka    43
# 20765               ምርጥ ዕቃ           @MerttEka    32
# 20766               ምርጥ ዕቃ           @MerttEka    30
# 20767               ምርጥ ዕቃ           @MerttEka    23
#
#                                                  Message  \
# 0        \n ባለሁለት ምድጃ ስቶቭ\n\n      \n\n 2000 ዋት\n ፊውዝ...
# 1      7pcs   \n\n አንድ ማራኪ ጆግና 6 መጠጫ ብርጭቆዎች\n የፈሳሽ መጠ...
# 2        -  \n\n      .\n360 °  \n100%  !!\n\nዋጋ፦    ...
# 3             \n\n          -    \nከ45cm እስከ 70cm መለጠ...
# 4             \n\n          -    \n\nዋጋ፦    2000 ብር\n...
# ...                                                  ...
# 20763                                               2500
# 20764                                ዋጋ 2500\n0983063957
# 20765  የሙያ ባለቤት መሆን መሠልጠን ነው።\nቀለም ቀቢ ሳያስፈልግዎ ቤትዎን ወይ...
# 20766  ቤትና ግቢዎን እንዲሁም የብረት እና የእንጨት ቁሳቁስዎን ቀለም ቀቢ ሳያስ...
# 20767                                        ለማዘዝ\n ://.
#
#                             Date                               Media Path
# 0      2025-06-19 06:31:31+00:00  data/photos/@Shageronlinestore_7383.jpg
# 1      2025-06-18 11:19:11+00:00  data/photos/@Shageronlinestore_7382.jpg
# 2      2025-06-18 07:12:03+00:00                                      NaN
# 3      2025-06-17 18:32:21+00:00                                      NaN
# 4      2025-06-17 18:32:20+00:00  data/photos/@Shageronlinestore_7375.jpg
# ...                          ...                                      ...
# 20763  2019-11-13 10:01:12+00:00                                      NaN
# 20764  2019-11-13 10:00:40+00:00                                      NaN
# 20765  2019-11-09 04:44:54+00:00                                      NaN
# 20766  2019-10-31 07:06:25+00:00                                      NaN
# 20767  2019-10-27 13:38:49+00:00                                      NaN
#
# [20768 rows x 6 columns]

# %% [markdown]
# # Drop rows with missing values in the Message columns

# %%
df = df.dropna(subset=['Message'])

# %%
message_cleaned = df['Message'].isnull().sum()
print(f"Numer of NAN values in Message columns is {message_cleaned}")
# Out:
# Numer of NAN values in Message columns is 0

# %%
# Apply the updated function to the non-null messages
df['Labeled_Message'] = df['Message'].apply(l.label_message_utf8_with_birr)

# Display the updated DataFrame
df.head()
# Out:
#    Unnamed: 0        Channel Title    Channel Username    ID  \
# 0           0  Sheger online-store  @Shageronlinestore  7383
# 1           1  Sheger online-store  @Shageronlinestore  7382
# 2           6  Sheger online-store  @Shageronlinestore  7377
# 3           7  Sheger online-store  @Shageronlinestore  7376
# 4           8  Sheger online-store  @Shageronlinestore  7375
#
#                                              Message  \
# 0    \n ባለሁለት ምድጃ ስቶቭ\n\n      \n\n 2000 ዋት\n ፊውዝ...
# 1  7pcs   \n\n አንድ ማራኪ ጆግና 6 መጠጫ ብርጭቆዎች\n የፈሳሽ መጠ...
# 2    -  \n\n      .\n360 °  \n100%  !!\n\nዋጋ፦    ...
# 3         \n\n          -    \nከ45cm እስከ 70cm መለጠ...
# 4         \n\n          -    \n\nዋጋ፦    2000 ብር\n...
#
#                         Date                               Media Path  \
# 0  2025-06-19 06:31:31+00:00  data/photos/@Shageronlinestore_7383.jpg
# 1  2025-06-18 11:19:11+00:00  data/photos/@Shageronlinestore_7382.jpg
# 2  2025-06-18 07:12:03+00:00                                      NaN
# 3  2025-06-17 18:32:21+00:00                                      NaN
# 4  2025-06-17 18:32:20+00:00  data/photos/@Shageronlinestore_7375.jpg
#
#                                      Labeled_Message
# 0  ባለሁለት I-PRODUCT\nምድጃ I-PRODUCT\nስቶቭ B-PRODUCT\...
# 1  7pcs O\nአንድ O\nማራኪ O\nጆግና O\n6 O\nመጠጫ O\nብርጭቆዎ...
# 2  - O\n360 O\n° O\n100% O\n!! O\nዋጋ፦ O\n400 B-PR...
# 3  - O\nከ45cm O\nእስከ O\n70cm O\nመለጠጥ O\nየሚችል O\nዋ...
# 4  - O\nዋጋ፦ O\n2000 B-PRICE\nብር I-PRICE\nውስን O\nፍ...

# %%
# Save the updated labeled dataset to a file in CoNLL format
labeled_data_birr_path = '../data/labeled_telegram_product_price_location.txt-'
with open(labeled_data_birr_path, 'w', encoding='utf-8') as f:
    for index, row in df.iterrows():
        f.write(f"{row['Labeled_Message']}\n\n")

# %%
# Save the labeled data to a .conll file
conll_file_path = '../data/@Shageonlinestore_labeled_data.conll'
with open(conll_file_path, 'w', encoding='utf-8') as f:
    for labeled_message in df['Labeled_Message']:
        f.write(f"{labeled_message}\n\n")

print(f"Labeled data saved to {conll_file_path}")
# Out:
# Labeled data saved to ../data/@Shageonlinestore_labeled_data.conll
